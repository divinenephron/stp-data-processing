# %% [markdown]
# Scenario 1
# ====
#
# Instructions
# ----
# The reference ranges for the Blood Science Lab need to be audited. The potassium reference range is usually calculated using data from general practices, so please can you calculate this using requests from 2018.
#
# Load data
# ----

# %%
# First select this box and press shift-enter to load the data
suppressMessages(library(tidyverse))
data <- read.csv("data/scenario_1.csv")
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 3.4.4”Warning message:
# “package ‘tidyr’ was built under R version 3.4.4”Warning message:
# “package ‘purrr’ was built under R version 3.4.4”Warning message:
# “package ‘dplyr’ was built under R version 3.4.4”Warning message:
# “package ‘stringr’ was built under R version 3.4.4”

# %% [markdown]
# Code
# ----

# %%
# Then select this box and press shift-enter to run it
data %>%
filter(source == "GP") %>%
filter(!is.na(potassium)) %>%
summarise(mean = mean(potassium), sd = sd(potassium))
# Out:
# Warning message:
# “package ‘bindrcpp’ was built under R version 3.4.4”
#   mean     sd
# 1 4.256779 0.3702909

# %%
# To show the original data select this box and press shift-enter
data
# Out:
#     id  source    potassium sodium
# 1    1  GP        4.426225  NA
# 2    2  GP        3.976302  NA
# 3    3  GP        4.380191  NA
# 4    4  GP        4.624259  NA
# 5    5  GP        4.091348  NA
# 6    6  GP        3.806336  NA
# 7    7  GP        4.221630  NA
# 8    8  GP        4.611289  NA
# 9    9  GP        3.500265  NA
# 10  10  GP        4.377958  NA
# 11  11  GP        3.816019  NA
# 12  12  GP        4.450865  NA
# 13  13  GP        4.017278  NA
# 14  14  GP        3.661648  NA
# 15  15  GP        4.193643  NA
# 16  16  GP        3.624340  NA
# 17  17  GP        4.131734  NA
# 18  18  GP        3.629832  NA
# 19  19  GP        4.703874  NA
# 20  20  GP        4.204359  NA
# 21  21  GP        4.271740  NA
# 22  22  GP        4.071847  NA
# 23  23  GP        3.723691  NA
# 24  24  GP        4.796723  NA
# 25  25  GP        4.574885  NA
# 26  26  GP        3.954007  NA
# 27  27  GP        4.261599  NA
# 28  28  GP        4.081237  NA
# 29  29  GP        4.486364  NA
# 30  30  GP        4.211481  NA
# ⋮   ⋮   ⋮         ⋮         ⋮
# 771 371 INPATIENT NA        136.9516
# 772 372 INPATIENT NA        136.4334
# 773 373 INPATIENT NA        141.0030
# 774 374 INPATIENT NA        140.4152
# 775 375 INPATIENT NA        146.1233
# 776 376 INPATIENT NA        141.3447
# 777 377 INPATIENT NA        139.2513
# 778 378 INPATIENT NA        130.6256
# 779 379 INPATIENT NA        134.1018
# 780 380 INPATIENT NA        138.6795
# 781 381 INPATIENT NA        134.2764
# 782 382 INPATIENT NA        135.9458
# 783 383 INPATIENT NA        139.1948
# 784 384 INPATIENT NA        139.6061
# 785 385 INPATIENT NA        137.1928
# 786 386 INPATIENT NA        135.2255
# 787 387 INPATIENT NA        139.7163
# 788 388 INPATIENT NA        139.3013
# 789 389 INPATIENT NA        141.2641
# 790 390 INPATIENT NA        134.3876
# 791 391 INPATIENT NA        144.7891
# 792 392 INPATIENT NA        142.5384
# 793 393 INPATIENT NA        133.9805
# 794 394 INPATIENT NA        137.9505
# 795 395 INPATIENT NA        134.9665
# 796 396 INPATIENT NA        139.5809
# 797 397 INPATIENT NA        141.2759
# 798 398 INPATIENT NA        136.7243
# 799 399 INPATIENT NA        138.6254
# 800 400 INPATIENT NA        139.9533
